# %% [markdown]
# # Building a Twitter Streamer
# * Apply Twitter's StreamListener to gather data on a continuous basis
# * Store data as a csv and save the file
#
# ## Imports

# %%
import tweepy as tw
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import pickle
import re
from json import JSONEncoder
from bson import ObjectId
from sklearn.feature_extraction.text import CountVectorizer
from datetime import datetime
from pprint import pprint
from pymongo import MongoClient

# %matplotlib inline

# %% [markdown]
# ## Load Twitter Permissions and connect to Twitter using Tweepy

# %%
# Use 'with' to open file since it will automatically close the file
with open('/Users/shirlwilliams/Documents/.permission files/twitter_perms.json') as f:
    d = json.load(f)

# %%
# Create the auth
auth = tw.OAuthHandler(consumer_key=d['consumer_key'], consumer_secret=d['consumer_secret'])
auth.set_access_token(key=d['access_token'], secret=d['access_token_secret'])

# %%
# Create the API by passing in the auth
api = tw.API(auth_handler=auth)

# %%
# # Check the connection with a basic search
# for tweet in api.search('#COVID'):
#     print(tweet._json)

# %% [markdown]
# ## Run mongod in terminal and connect to it using pymongo.MongoClient

# %%
# Connect
client = MongoClient(port=27017, host='localhost')

# %%
# Collection
tweets = client['tweets']

# %%
# Mongo is built on json formatting so everything reads like a dictionary
covid_tweets = tweets["covid"]

# %%
# New collection called covid
covid = covid_tweets['covid']

# %%
# We don't see the collection since a collection needs a document in 
# order to get built
#covid_tweets.list_collection_names()

# %% [markdown]
# # Build a StreamListener to obtain tweets

# %%
# Child class of StreamListener class
class MyStreamListener(tw.StreamListener):  
    
    def on_status(self, status):  
        covid_tweets.insert_one(status._json)
        print('inserted tweet, now db has {} tweets'.format(covid_tweets.count_documents(filter={})))
        pass
        
        
    def on_error(self, status_code):
        if status_code == 420:
            print('Encountered and error (', status_code, ')')
            return False

# %%
# This is the listener
myStreamListener = MyStreamListener()
myStream = tw.Stream(auth = api.auth, listener=myStreamListener, tweet_mode='extended')

# %%
# Filter
myStream.filter(track=['covid', '#covid', 'shelter', 'COVID', '#COVID', 'pandemic'])
# Out:
# inserted tweet, now db has 225097 tweets
# inserted tweet, now db has 225098 tweets
# inserted tweet, now db has 225099 tweets
# inserted tweet, now db has 225100 tweets
# inserted tweet, now db has 225101 tweets
# inserted tweet, now db has 225102 tweets
# inserted tweet, now db has 225103 tweets
# inserted tweet, now db has 225104 tweets
# inserted tweet, now db has 225105 tweets
# inserted tweet, now db has 225106 tweets
# inserted tweet, now db has 225107 tweets
# inserted tweet, now db has 225108 tweets
# inserted tweet, now db has 225109 tweets
# inserted tweet, now db has 225110 tweets
# inserted tweet, now db has 225111 tweets
# inserted tweet, now db has 225112 tweets
# inserted tweet, now db has 225113 tweets
# inserted tweet, now db has 225114 tweets
# inserted tweet, now db has 225115 tweets
# inserted tweet, now db has 225116 tweets
# inserted tweet, now db has 225117 tweets
# inserted tweet, now db has 225118 tweets
# inserted tweet, now db has 225119 tweets
# inserted tweet, now db has 225120 tweets
# inserted tweet, now db has 225121 tweets
# inserted tweet, now db has 225122 tweets
# inserted tweet, now db has 225123 tweets
# inserted tweet, now db has 225124 tweets
# inserted tweet, now db has 225125 tweets
# inserted tweet, now db has 225126 tweets
# inserted tweet, now db has 225127 tweets
# inserted tweet, now db has 225128 tweets
# inserted tweet, now db has 225129 tweets
# inserted tweet, now db has 225130 tweets
# inserted tweet, now db has 225131 tweets
# inserted tweet, now db has 225132 tweets
# inserted tweet, now db has 225133 tweets
# inserted tweet, now db has 225134 tweets
# inserted tweet, now db has 225135 tweets
# inserted tweet, now db has 225136 tweets
# inserted tweet, now db has 225137 tweets
# inserted tweet, now db has 225138 tweets
# inserted tweet, now db has 225139 tweets
# inserted tweet, now db has 225140 tweets
# inserted tweet, now db has 225141 tweets
# inserted tweet, now db has 225142 tweets
# inserted tweet, now db has 225143 tweets
# inserted tweet, now db has 225144 tweets
# inserted tweet, now db has 225145 tweets
# inserted tweet, now db has 225146 tweets
# inserted tweet, now db has 225147 tweets
# inserted tweet, now db has 225148 tweets
# inserted tweet, now db has 225149 tweets
# inserted tweet, now db has 225150 tweets
# inserted tweet, now db has 225151 tweets
# inserted tweet, now db has 225152 tweets
# inserted tweet, now db has 225153 tweets
# inserted tweet, now db has 225154 tweets
# inserted tweet, now db has 225155 tweets
# inserted tweet, now db has 225156 tweets
# inserted tweet, now db has 225157 tweets
# inserted tweet, now db has 225158 tweets
# inserted tweet, now db has 225159 tweets
# inserted tweet, now db has 225160 tweets
# inserted tweet, now db has 225161 tweets
# inserted tweet, now db has 225162 tweets
# inserted tweet, now db has 225163 tweets
# inserted tweet, now db has 225164 tweets
# inserted tweet, now db has 225165 tweets
# inserted tweet, now db has 225166 tweets
# inserted tweet, now db has 225167 tweets
# inserted tweet, now db has 225168 tweets
# inserted tweet, now db has 225169 tweets
# inserted tweet, now db has 225170 tweets
# inserted tweet, now db has 225171 tweets
# inserted tweet, now db has 225172 tweets
# inserted tweet, now db has 225173 tweets
# inserted tweet, now db has 225174 tweets
# inserted tweet, now db has 225175 tweets
# inserted tweet, now db has 225176 tweets
# inserted tweet, now db has 225177 tweets
# inserted tweet, now db has 225178 tweets
# inserted tweet, now db has 225179 tweets
# inserted tweet, now db has 225180 tweets
# inserted tweet, now db has 225181 tweets
# inserted tweet, now db has 225182 tweets
# inserted tweet, now db has 225183 tweets
# inserted tweet, now db has 225184 tweets
# inserted tweet, now db has 225185 tweets
# inserted tweet, now db has 225186 tweets
# inserted tweet, now db has 225187 tweets
# inserted tweet, now db has 225188 tweets
# inserted tweet, now db has 225189 tweets
# inserted tweet, now db has 225190 tweets
# inserted tweet, now db has 225191 tweets
# inserted tweet, now db has 225192 tweets
# inserted tweet, now db has 225193 tweets
# inserted tweet, now db has 225194 tweets
# inserted tweet, now db has 225195 tweets
# inserted tweet, now db has 225196 tweets
# inserted tweet, now db has 225197 tweets
# inserted tweet, now db has 225198 tweets
# inserted tweet, now db has 225199 tweets
# inserted tweet, now db has 225200 tweets
# inserted tweet, now db has 225201 tweets
# inserted tweet, now db has 225202 tweets
# inserted tweet, now db has 225203 tweets
# inserted tweet, now db has 225204 tweets
# inserted tweet, now db has 225205 tweets
# inserted tweet, now db has 225206 tweets
# inserted tweet, now db has 225207 tweets
# inserted tweet, now db has 225208 tweets
# inserted tweet, now db has 225209 tweets
# inserted tweet, now db has 225210 tweets
# inserted tweet, now db has 225211 tweets
# inserted tweet, now db has 225212 tweets
# inserted tweet, now db has 225213 tweets
# inserted tweet, now db has 225214 tweets
# inserted tweet, now db has 225215 tweets
# inserted tweet, now db has 225216 tweets
# inserted tweet, now db has 225217 tweets
# inserted tweet, now db has 225218 tweets
# inserted tweet, now db has 225219 tweets
# inserted tweet, now db has 225220 tweets
# inserted tweet, now db has 225221 tweets
# inserted tweet, now db has 225222 tweets
# inserted tweet, now db has 225223 tweets
# inserted tweet, now db has 225224 tweets
# inserted tweet, now db has 225225 tweets
# inserted tweet, now db has 225226 tweets
# inserted tweet, now db has 225227 tweets
# inserted tweet, now db has 225228 tweets
# inserted tweet, now db has 225229 tweets
# inserted tweet, now db has 225230 tweets
# inserted tweet, now db has 225231 tweets
# inserted tweet, now db has 225232 tweets
# inserted tweet, now db has 225233 tweets
# inserted tweet, now db has 225234 tweets
# inserted tweet, now db has 225235 tweets
# inserted tweet, now db has 225236 tweets
# inserted tweet, now db has 225237 tweets
# inserted tweet, now db has 225238 tweets
# inserted tweet, now db has 225239 tweets
# inserted tweet, now db has 225240 tweets
# inserted tweet, now db has 225241 tweets
# inserted tweet, now db has 225242 tweets
# inserted tweet, now db has 225243 tweets
# inserted tweet, now db has 225244 tweets
# inserted tweet, now db has 225245 tweets
# inserted tweet, now db has 225246 tweets
# inserted tweet, now db has 225247 tweets
# inserted tweet, now db has 225248 tweets
# inserted tweet, now db has 225249 tweets
# inserted tweet, now db has 225250 tweets
# inserted tweet, now db has 225251 tweets
# inserted tweet, now db has 225252 tweets
# inserted tweet, now db has 225253 tweets
# inserted tweet, now db has 225254 tweets
# inserted tweet, now db has 225255 tweets
# inserted tweet, now db has 225256 tweets
# inserted tweet, now db has 225257 tweets
# inserted tweet, now db has 225258 tweets
# inserted tweet, now db has 225259 tweets
# inserted tweet, now db has 225260 tweets
# inserted tweet, now db has 225261 tweets
# inserted tweet, now db has 225262 tweets
# inserted tweet, now db has 225263 tweets
# inserted tweet, now db has 225264 tweets
# inserted tweet, now db has 225265 tweets
# inserted tweet, now db has 225266 tweets
# inserted tweet, now db has 225267 tweets
# inserted tweet, now db has 225268 tweets
# inserted tweet, now db has 225269 tweets
# inserted tweet, now db has 225270 tweets
# inserted tweet, now db has 225271 tweets
# inserted tweet, now db has 225272 tweets
# inserted tweet, now db has 225273 tweets
# inserted tweet, now db has 225274 tweets
# inserted tweet, now db has 225275 tweets
# inserted tweet, now db has 225276 tweets
# inserted tweet, now db has 225277 tweets
# inserted tweet, now db has 225278 tweets
# inserted tweet, now db has 225279 tweets
# inserted tweet, now db has 225280 tweets
# inserted tweet, now db has 225281 tweets
# inserted tweet, now db has 225282 tweets
# inserted tweet, now db has 225283 tweets
# inserted tweet, now db has 225284 tweets
# inserted tweet, now db has 225285 tweets
# inserted tweet, now db has 225286 tweets
# inserted tweet, now db has 225287 tweets
# inserted tweet, now db has 225288 tweets
# inserted tweet, now db has 225289 tweets
# inserted tweet, now db has 225290 tweets
# inserted tweet, now db has 225291 tweets
# inserted tweet, now db has 225292 tweets
# inserted tweet, now db has 225293 tweets
# inserted tweet, now db has 225294 tweets
# inserted tweet, now db has 225295 tweets
# inserted tweet, now db has 225296 tweets
# inserted tweet, now db has 225297 tweets
# inserted tweet, now db has 225298 tweets
# inserted tweet, now db has 225299 tweets
# inserted tweet, now db has 225300 tweets
# inserted tweet, now db has 225301 tweets
# inserted tweet, now db has 225302 tweets
# inserted tweet, now db has 225303 tweets
# inserted tweet, now db has 225304 tweets
# inserted tweet, now db has 225305 tweets
# inserted tweet, now db has 225306 tweets
# inserted tweet, now db has 225307 tweets
# inserted tweet, now db has 225308 tweets
# inserted tweet, now db has 225309 tweets
# inserted tweet, now db has 225310 tweets
# inserted tweet, now db has 225311 tweets
# inserted tweet, now db has 225312 tweets
# inserted tweet, now db has 225313 tweets
# inserted tweet, now db has 225314 tweets
# inserted tweet, now db has 225315 tweets
# inserted tweet, now db has 225316 tweets
# inserted tweet, now db has 225317 tweets
# inserted tweet, now db has 225318 tweets
# inserted tweet, now db has 225319 tweets
# inserted tweet, now db has 225320 tweets
# inserted tweet, now db has 225321 tweets
# inserted tweet, now db has 225322 tweets
# inserted tweet, now db has 225323 tweets
# inserted tweet, now db has 225324 tweets
# inserted tweet, now db has 225325 tweets
# inserted tweet, now db has 225326 tweets
# inserted tweet, now db has 225327 tweets
# inserted tweet, now db has 225328 tweets
# inserted tweet, now db has 225329 tweets
# inserted tweet, now db has 225330 tweets
# inserted tweet, now db has 225331 tweets
# inserted tweet, now db has 225332 tweets
# inserted tweet, now db has 225333 tweets
# inserted tweet, now db has 225334 tweets
# inserted tweet, now db has 225335 tweets
# inserted tweet, now db has 225336 tweets
# inserted tweet, now db has 225337 tweets
# inserted tweet, now db has 225338 tweets
# inserted tweet, now db has 225339 tweets
# inserted tweet, now db has 225340 tweets
# inserted tweet, now db has 225341 tweets
# inserted tweet, now db has 225342 tweets
# inserted tweet, now db has 225343 tweets
# inserted tweet, now db has 225344 tweets
# inserted tweet, now db has 225345 tweets
# inserted tweet, now db has 225346 tweets
# inserted tweet, now db has 225347 tweets
# inserted tweet, now db has 225348 tweets
# inserted tweet, now db has 225349 tweets
# inserted tweet, now db has 225350 tweets
# inserted tweet, now db has 225351 tweets
# inserted tweet, now db has 225352 tweets
# inserted tweet, now db has 225353 tweets
# inserted tweet, now db has 225354 tweets
# inserted tweet, now db has 225355 tweets
# inserted tweet, now db has 225356 tweets
# inserted tweet, now db has 225357 tweets
# inserted tweet, now db has 225358 tweets
# inserted tweet, now db has 225359 tweets
# inserted tweet, now db has 225360 tweets
# inserted tweet, now db has 225361 tweets
# inserted tweet, now db has 225362 tweets
# inserted tweet, now db has 225363 tweets
# inserted tweet, now db has 225364 tweets
# inserted tweet, now db has 225365 tweets
# inserted tweet, now db has 225366 tweets
# inserted tweet, now db has 225367 tweets
# inserted tweet, now db has 225368 tweets
# inserted tweet, now db has 225369 tweets
# inserted tweet, now db has 225370 tweets
# inserted tweet, now db has 225371 tweets
# inserted tweet, now db has 225372 tweets
# inserted tweet, now db has 225373 tweets
# inserted tweet, now db has 225374 tweets
# inserted tweet, now db has 225375 tweets
# inserted tweet, now db has 225376 tweets
# inserted tweet, now db has 225377 tweets
# inserted tweet, now db has 225378 tweets
# inserted tweet, now db has 225379 tweets
# inserted tweet, now db has 225380 tweets
# inserted tweet, now db has 225381 tweets
# inserted tweet, now db has 225382 tweets
# inserted tweet, now db has 225383 tweets
# inserted tweet, now db has 225384 tweets
# inserted tweet, now db has 225385 tweets
# inserted tweet, now db has 225386 tweets
# inserted tweet, now db has 225387 tweets
# inserted tweet, now db has 225388 tweets
# inserted tweet, now db has 225389 tweets
# inserted tweet, now db has 225390 tweets
# inserted tweet, now db has 225391 tweets
# inserted tweet, now db has 225392 tweets
# inserted tweet, now db has 225393 tweets
# inserted tweet, now db has 225394 tweets
# inserted tweet, now db has 225395 tweets
# inserted tweet, now db has 225396 tweets
# inserted tweet, now db has 225397 tweets
# inserted tweet, now db has 225398 tweets
# inserted tweet, now db has 225399 tweets
# inserted tweet, now db has 225400 tweets
# inserted tweet, now db has 225401 tweets
# inserted tweet, now db has 225402 tweets
# inserted tweet, now db has 225403 tweets
# inserted tweet, now db has 225404 tweets
# inserted tweet, now db has 225405 tweets
# inserted tweet, now db has 225406 tweets
# inserted tweet, now db has 225407 tweets
# inserted tweet, now db has 225408 tweets
# inserted tweet, now db has 225409 tweets
# inserted tweet, now db has 225410 tweets
# inserted tweet, now db has 225411 tweets
# inserted tweet, now db has 225412 tweets
# inserted tweet, now db has 225413 tweets
# inserted tweet, now db has 225414 tweets
# inserted tweet, now db has 225415 tweets
# inserted tweet, now db has 225416 tweets
# inserted tweet, now db has 225417 tweets
# inserted tweet, now db has 225418 tweets
# inserted tweet, now db has 225419 tweets
# inserted tweet, now db has 225420 tweets
# inserted tweet, now db has 225421 tweets
# inserted tweet, now db has 225422 tweets
# inserted tweet, now db has 225423 tweets
# inserted tweet, now db has 225424 tweets
# inserted tweet, now db has 225425 tweets
# inserted tweet, now db has 225426 tweets
# inserted tweet, now db has 225427 tweets
# inserted tweet, now db has 225428 tweets
# inserted tweet, now db has 225429 tweets
# inserted tweet, now db has 225430 tweets
# inserted tweet, now db has 225431 tweets
# inserted tweet, now db has 225432 tweets
# inserted tweet, now db has 225433 tweets
# inserted tweet, now db has 225434 tweets
# inserted tweet, now db has 225435 tweets
# inserted tweet, now db has 225436 tweets
# inserted tweet, now db has 225437 tweets
# inserted tweet, now db has 225438 tweets
# inserted tweet, now db has 225439 tweets
# inserted tweet, now db has 225440 tweets
# inserted tweet, now db has 225441 tweets
# inserted tweet, now db has 225442 tweets
# inserted tweet, now db has 225443 tweets
# inserted tweet, now db has 225444 tweets
# inserted tweet, now db has 225445 tweets
# inserted tweet, now db has 225446 tweets
# inserted tweet, now db has 225447 tweets
# inserted tweet, now db has 225448 tweets
# inserted tweet, now db has 225449 tweets
# inserted tweet, now db has 225450 tweets
# inserted tweet, now db has 225451 tweets
# inserted tweet, now db has 225452 tweets
# inserted tweet, now db has 225453 tweets
# inserted tweet, now db has 225454 tweets
# inserted tweet, now db has 225455 tweets
# inserted tweet, now db has 225456 tweets
# inserted tweet, now db has 225457 tweets
# inserted tweet, now db has 225458 tweets
# inserted tweet, now db has 225459 tweets
# inserted tweet, now db has 225460 tweets
# inserted tweet, now db has 225461 tweets
# inserted tweet, now db has 225462 tweets
# inserted tweet, now db has 225463 tweets
# inserted tweet, now db has 225464 tweets
# inserted tweet, now db has 225465 tweets
# inserted tweet, now db has 225466 tweets
# inserted tweet, now db has 225467 tweets
# inserted tweet, now db has 225468 tweets
# inserted tweet, now db has 225469 tweets
# inserted tweet, now db has 225470 tweets
# inserted tweet, now db has 225471 tweets
# inserted tweet, now db has 225472 tweets
# inserted tweet, now db has 225473 tweets
# inserted tweet, now db has 225474 tweets
# inserted tweet, now db has 225475 tweets
# inserted tweet, now db has 225476 tweets
# inserted tweet, now db has 225477 tweets
# inserted tweet, now db has 225478 tweets
# inserted tweet, now db has 225479 tweets
# inserted tweet, now db has 225480 tweets
# inserted tweet, now db has 225481 tweets
# inserted tweet, now db has 225482 tweets
# inserted tweet, now db has 225483 tweets
# inserted tweet, now db has 225484 tweets
# inserted tweet, now db has 225485 tweets
# inserted tweet, now db has 225486 tweets
# inserted tweet, now db has 225487 tweets
# inserted tweet, now db has 225488 tweets
# inserted tweet, now db has 225489 tweets
# inserted tweet, now db has 225490 tweets
# inserted tweet, now db has 225491 tweets
# inserted tweet, now db has 225492 tweets
# inserted tweet, now db has 225493 tweets
# inserted tweet, now db has 225494 tweets
# inserted tweet, now db has 225495 tweets
# inserted tweet, now db has 225496 tweets
# inserted tweet, now db has 225497 tweets
# inserted tweet, now db has 225498 tweets
# inserted tweet, now db has 225499 tweets
# inserted tweet, now db has 225500 tweets
# inserted tweet, now db has 225501 tweets
# inserted tweet, now db has 225502 tweets
# inserted tweet, now db has 225503 tweets
# inserted tweet, now db has 225504 tweets
# inserted tweet, now db has 225505 tweets
# inserted tweet, now db has 225506 tweets
# inserted tweet, now db has 225507 tweets
# inserted tweet, now db has 225508 tweets
# inserted tweet, now db has 225509 tweets
# inserted tweet, now db has 225510 tweets
# inserted tweet, now db has 225511 tweets
# inserted tweet, now db has 225512 tweets
# inserted tweet, now db has 225513 tweets
# inserted tweet, now db has 225514 tweets
# inserted tweet, now db has 225515 tweets
# inserted tweet, now db has 225516 tweets
# inserted tweet, now db has 225517 tweets
# inserted tweet, now db has 225518 tweets
# inserted tweet, now db has 225519 tweets
# inserted tweet, now db has 225520 tweets
# inserted tweet, now db has 225521 tweets
# inserted tweet, now db has 225522 tweets
# inserted tweet, now db has 225523 tweets
# inserted tweet, now db has 225524 tweets
# inserted tweet, now db has 225525 tweets
# inserted tweet, now db has 225526 tweets
# inserted tweet, now db has 225527 tweets
# inserted tweet, now db has 225528 tweets
# inserted tweet, now db has 225529 tweets
# inserted tweet, now db has 225530 tweets
# inserted tweet, now db has 225531 tweets
# inserted tweet, now db has 225532 tweets
# inserted tweet, now db has 225533 tweets
# inserted tweet, now db has 225534 tweets
# inserted tweet, now db has 225535 tweets
# inserted tweet, now db has 225536 tweets
# inserted tweet, now db has 225537 tweets
# inserted tweet, now db has 225538 tweets
# inserted tweet, now db has 225539 tweets
# inserted tweet, now db has 225540 tweets
# inserted tweet, now db has 225541 tweets
# inserted tweet, now db has 225542 tweets
# inserted tweet, now db has 225543 tweets
# inserted tweet, now db has 225544 tweets
# inserted tweet, now db has 225545 tweets
# inserted tweet, now db has 225546 tweets
# inserted tweet, now db has 225547 tweets
# inserted tweet, now db has 225548 tweets
# inserted tweet, now db has 225549 tweets
# inserted tweet, now db has 225550 tweets
# inserted tweet, now db has 225551 tweets
# inserted tweet, now db has 225552 tweets
# inserted tweet, now db has 225553 tweets
# inserted tweet, now db has 225554 tweets
# inserted tweet, now db has 225555 tweets
# inserted tweet, now db has 225556 tweets
# inserted tweet, now db has 225557 tweets
# inserted tweet, now db has 225558 tweets
# inserted tweet, now db has 225559 tweets
# inserted tweet, now db has 225560 tweets
# inserted tweet, now db has 225561 tweets
# inserted tweet, now db has 225562 tweets
# inserted tweet, now db has 225563 tweets
# inserted tweet, now db has 225564 tweets
# inserted tweet, now db has 225565 tweets
# inserted tweet, now db has 225566 tweets
# inserted tweet, now db has 225567 tweets
# inserted tweet, now db has 225568 tweets
# inserted tweet, now db has 225569 tweets
# inserted tweet, now db has 225570 tweets
# inserted tweet, now db has 225571 tweets
# inserted tweet, now db has 225572 tweets
# inserted tweet, now db has 225573 tweets
# inserted tweet, now db has 225574 tweets
# inserted tweet, now db has 225575 tweets
# inserted tweet, now db has 225576 tweets
# inserted tweet, now db has 225577 tweets
# inserted tweet, now db has 225578 tweets
# inserted tweet, now db has 225579 tweets
# inserted tweet, now db has 225580 tweets
# inserted tweet, now db has 225581 tweets
# inserted tweet, now db has 225582 tweets
# inserted tweet, now db has 225583 tweets
# inserted tweet, now db has 225584 tweets
# inserted tweet, now db has 225585 tweets
# inserted tweet, now db has 225586 tweets
# inserted tweet, now db has 225587 tweets
# inserted tweet, now db has 225588 tweets
# inserted tweet, now db has 225589 tweets
# inserted tweet, now db has 225590 tweets
# inserted tweet, now db has 225591 tweets
# inserted tweet, now db has 225592 tweets
# inserted tweet, now db has 225593 tweets
# inserted tweet, now db has 225594 tweets
# inserted tweet, now db has 225595 tweets
# inserted tweet, now db has 225596 tweets
# inserted tweet, now db has 225597 tweets
# inserted tweet, now db has 225598 tweets
# inserted tweet, now db has 225599 tweets
# inserted tweet, now db has 225600 tweets
# inserted tweet, now db has 225601 tweets
# inserted tweet, now db has 225602 tweets
# inserted tweet, now db has 225603 tweets
# inserted tweet, now db has 225604 tweets
# inserted tweet, now db has 225605 tweets
# inserted tweet, now db has 225606 tweets
# inserted tweet, now db has 225607 tweets
# inserted tweet, now db has 225608 tweets
# inserted tweet, now db has 225609 tweets
# inserted tweet, now db has 225610 tweets
# inserted tweet, now db has 225611 tweets
# inserted tweet, now db has 225612 tweets
# inserted tweet, now db has 225613 tweets
# inserted tweet, now db has 225614 tweets
# inserted tweet, now db has 225615 tweets
# inserted tweet, now db has 225616 tweets
# inserted tweet, now db has 225617 tweets
# inserted tweet, now db has 225618 tweets
# inserted tweet, now db has 225619 tweets
# inserted tweet, now db has 225620 tweets
# inserted tweet, now db has 225621 tweets
# inserted tweet, now db has 225622 tweets
# inserted tweet, now db has 225623 tweets
# inserted tweet, now db has 225624 tweets
# inserted tweet, now db has 225625 tweets
# inserted tweet, now db has 225626 tweets
# inserted tweet, now db has 225627 tweets
# inserted tweet, now db has 225628 tweets
# inserted tweet, now db has 225629 tweets
# inserted tweet, now db has 225630 tweets
# inserted tweet, now db has 225631 tweets
# inserted tweet, now db has 225632 tweets
# inserted tweet, now db has 225633 tweets
# inserted tweet, now db has 225634 tweets
# inserted tweet, now db has 225635 tweets
# inserted tweet, now db has 225636 tweets
# inserted tweet, now db has 225637 tweets
# inserted tweet, now db has 225638 tweets
# inserted tweet, now db has 225639 tweets
# inserted tweet, now db has 225640 tweets
# inserted tweet, now db has 225641 tweets
# inserted tweet, now db has 225642 tweets
# inserted tweet, now db has 225643 tweets
# inserted tweet, now db has 225644 tweets
# inserted tweet, now db has 225645 tweets
# inserted tweet, now db has 225646 tweets
# inserted tweet, now db has 225647 tweets
# inserted tweet, now db has 225648 tweets
# inserted tweet, now db has 225649 tweets
# inserted tweet, now db has 225650 tweets
# inserted tweet, now db has 225651 tweets
# inserted tweet, now db has 225652 tweets
# inserted tweet, now db has 225653 tweets
# inserted tweet, now db has 225654 tweets
# inserted tweet, now db has 225655 tweets
# inserted tweet, now db has 225656 tweets
# inserted tweet, now db has 225657 tweets
# inserted tweet, now db has 225658 tweets
# inserted tweet, now db has 225659 tweets
# inserted tweet, now db has 225660 tweets
# inserted tweet, now db has 225661 tweets
# inserted tweet, now db has 225662 tweets
# inserted tweet, now db has 225663 tweets
# inserted tweet, now db has 225664 tweets
# inserted tweet, now db has 225665 tweets
# inserted tweet, now db has 225666 tweets
# inserted tweet, now db has 225667 tweets
# inserted tweet, now db has 225668 tweets
# inserted tweet, now db has 225669 tweets
# inserted tweet, now db has 225670 tweets
# inserted tweet, now db has 225671 tweets
# inserted tweet, now db has 225672 tweets
# inserted tweet, now db has 225673 tweets
# inserted tweet, now db has 225674 tweets
# inserted tweet, now db has 225675 tweets
# inserted tweet, now db has 225676 tweets
# inserted tweet, now db has 225677 tweets
# inserted tweet, now db has 225678 tweets
# inserted tweet, now db has 225679 tweets
# inserted tweet, now db has 225680 tweets
# inserted tweet, now db has 225681 tweets
# inserted tweet, now db has 225682 tweets
# inserted tweet, now db has 225683 tweets
# inserted tweet, now db has 225684 tweets
# inserted tweet, now db has 225685 tweets
# inserted tweet, now db has 225686 tweets
# inserted tweet, now db has 225687 tweets
# inserted tweet, now db has 225688 tweets
# inserted tweet, now db has 225689 tweets
# inserted tweet, now db has 225690 tweets
# inserted tweet, now db has 225691 tweets
# inserted tweet, now db has 225692 tweets
# inserted tweet, now db has 225693 tweets
# inserted tweet, now db has 225694 tweets
# inserted tweet, now db has 225695 tweets
# inserted tweet, now db has 225696 tweets
# inserted tweet, now db has 225697 tweets
# inserted tweet, now db has 225698 tweets
# inserted tweet, now db has 225699 tweets
# inserted tweet, now db has 225700 tweets
# inserted tweet, now db has 225701 tweets
# inserted tweet, now db has 225702 tweets
# inserted tweet, now db has 225703 tweets
# inserted tweet, now db has 225704 tweets
# inserted tweet, now db has 225705 tweets
# inserted tweet, now db has 225706 tweets
# inserted tweet, now db has 225707 tweets
# inserted tweet, now db has 225708 tweets
# inserted tweet, now db has 225709 tweets
# inserted tweet, now db has 225710 tweets
# inserted tweet, now db has 225711 tweets
# inserted tweet, now db has 225712 tweets
# inserted tweet, now db has 225713 tweets
# inserted tweet, now db has 225714 tweets
# inserted tweet, now db has 225715 tweets
# inserted tweet, now db has 225716 tweets
# inserted tweet, now db has 225717 tweets
# inserted tweet, now db has 225718 tweets
# inserted tweet, now db has 225719 tweets
# inserted tweet, now db has 225720 tweets
# inserted tweet, now db has 225721 tweets
# inserted tweet, now db has 225722 tweets
# inserted tweet, now db has 225723 tweets
# inserted tweet, now db has 225724 tweets
# inserted tweet, now db has 225725 tweets
# inserted tweet, now db has 225726 tweets
# inserted tweet, now db has 225727 tweets
# inserted tweet, now db has 225728 tweets
# inserted tweet, now db has 225729 tweets
# inserted tweet, now db has 225730 tweets
# inserted tweet, now db has 225731 tweets
# inserted tweet, now db has 225732 tweets
# inserted tweet, now db has 225733 tweets
# inserted tweet, now db has 225734 tweets
# inserted tweet, now db has 225735 tweets
# inserted tweet, now db has 225736 tweets
# inserted tweet, now db has 225737 tweets
# inserted tweet, now db has 225738 tweets
# inserted tweet, now db has 225739 tweets
# inserted tweet, now db has 225740 tweets
# inserted tweet, now db has 225741 tweets
# inserted tweet, now db has 225742 tweets
# inserted tweet, now db has 225743 tweets
# inserted tweet, now db has 225744 tweets
# inserted tweet, now db has 225745 tweets
# inserted tweet, now db has 225746 tweets
# inserted tweet, now db has 225747 tweets
# inserted tweet, now db has 225748 tweets
# inserted tweet, now db has 225749 tweets
# inserted tweet, now db has 225750 tweets
# inserted tweet, now db has 225751 tweets
# inserted tweet, now db has 225752 tweets
# inserted tweet, now db has 225753 tweets
# inserted tweet, now db has 225754 tweets
# inserted tweet, now db has 225755 tweets
# inserted tweet, now db has 225756 tweets
# inserted tweet, now db has 225757 tweets
# inserted tweet, now db has 225758 tweets
# inserted tweet, now db has 225759 tweets
# inserted tweet, now db has 225760 tweets
# inserted tweet, now db has 225761 tweets
# inserted tweet, now db has 225762 tweets
# inserted tweet, now db has 225763 tweets
# inserted tweet, now db has 225764 tweets
# inserted tweet, now db has 225765 tweets
# inserted tweet, now db has 225766 tweets
# inserted tweet, now db has 225767 tweets
# inserted tweet, now db has 225768 tweets
# inserted tweet, now db has 225769 tweets
# inserted tweet, now db has 225770 tweets
# inserted tweet, now db has 225771 tweets
# inserted tweet, now db has 225772 tweets
# inserted tweet, now db has 225773 tweets
# inserted tweet, now db has 225774 tweets
# inserted tweet, now db has 225775 tweets
# inserted tweet, now db has 225776 tweets
# inserted tweet, now db has 225777 tweets
# inserted tweet, now db has 225778 tweets
# inserted tweet, now db has 225779 tweets
# inserted tweet, now db has 225780 tweets
# inserted tweet, now db has 225781 tweets
# inserted tweet, now db has 225782 tweets
# inserted tweet, now db has 225783 tweets
# inserted tweet, now db has 225784 tweets
# inserted tweet, now db has 225785 tweets
# inserted tweet, now db has 225786 tweets
# inserted tweet, now db has 225787 tweets
# inserted tweet, now db has 225788 tweets
# inserted tweet, now db has 225789 tweets
# inserted tweet, now db has 225790 tweets
# inserted tweet, now db has 225791 tweets
# inserted tweet, now db has 225792 tweets
# inserted tweet, now db has 225793 tweets
# inserted tweet, now db has 225794 tweets
# inserted tweet, now db has 225795 tweets
# inserted tweet, now db has 225796 tweets
# inserted tweet, now db has 225797 tweets
# inserted tweet, now db has 225798 tweets
# inserted tweet, now db has 225799 tweets
# inserted tweet, now db has 225800 tweets
# inserted tweet, now db has 225801 tweets
# inserted tweet, now db has 225802 tweets
# inserted tweet, now db has 225803 tweets
# inserted tweet, now db has 225804 tweets
# inserted tweet, now db has 225805 tweets
# inserted tweet, now db has 225806 tweets
# inserted tweet, now db has 225807 tweets
# inserted tweet, now db has 225808 tweets
# inserted tweet, now db has 225809 tweets
# inserted tweet, now db has 225810 tweets
# inserted tweet, now db has 225811 tweets
# inserted tweet, now db has 225812 tweets
# inserted tweet, now db has 225813 tweets
# inserted tweet, now db has 225814 tweets
# inserted tweet, now db has 225815 tweets
# inserted tweet, now db has 225816 tweets
# inserted tweet, now db has 225817 tweets
# inserted tweet, now db has 225818 tweets
# inserted tweet, now db has 225819 tweets
# inserted tweet, now db has 225820 tweets
# inserted tweet, now db has 225821 tweets
# inserted tweet, now db has 225822 tweets
# inserted tweet, now db has 225823 tweets
# inserted tweet, now db has 225824 tweets
# inserted tweet, now db has 225825 tweets
# inserted tweet, now db has 225826 tweets
# inserted tweet, now db has 225827 tweets
# inserted tweet, now db has 225828 tweets
# inserted tweet, now db has 225829 tweets
# inserted tweet, now db has 225830 tweets
# inserted tweet, now db has 225831 tweets
# inserted tweet, now db has 225832 tweets
# inserted tweet, now db has 225833 tweets
# inserted tweet, now db has 225834 tweets
# inserted tweet, now db has 225835 tweets
# inserted tweet, now db has 225836 tweets
# inserted tweet, now db has 225837 tweets
# inserted tweet, now db has 225838 tweets
# inserted tweet, now db has 225839 tweets
# inserted tweet, now db has 225840 tweets
# inserted tweet, now db has 225841 tweets
# inserted tweet, now db has 225842 tweets
# inserted tweet, now db has 225843 tweets
# inserted tweet, now db has 225844 tweets
# inserted tweet, now db has 225845 tweets
# inserted tweet, now db has 225846 tweets
# inserted tweet, now db has 225847 tweets
# inserted tweet, now db has 225848 tweets
# inserted tweet, now db has 225849 tweets
# inserted tweet, now db has 225850 tweets
# inserted tweet, now db has 225851 tweets
# inserted tweet, now db has 225852 tweets
# inserted tweet, now db has 225853 tweets
# inserted tweet, now db has 225854 tweets
# inserted tweet, now db has 225855 tweets
# inserted tweet, now db has 225856 tweets
# inserted tweet, now db has 225857 tweets
# inserted tweet, now db has 225858 tweets
# inserted tweet, now db has 225859 tweets
# inserted tweet, now db has 225860 tweets
# inserted tweet, now db has 225861 tweets
# inserted tweet, now db has 225862 tweets
# inserted tweet, now db has 225863 tweets
# inserted tweet, now db has 225864 tweets
# inserted tweet, now db has 225865 tweets
# inserted tweet, now db has 225866 tweets
# inserted tweet, now db has 225867 tweets
# inserted tweet, now db has 225868 tweets
# inserted tweet, now db has 225869 tweets
# inserted tweet, now db has 225870 tweets
# inserted tweet, now db has 225871 tweets
# inserted tweet, now db has 225872 tweets
# inserted tweet, now db has 225873 tweets
# inserted tweet, now db has 225874 tweets
# inserted tweet, now db has 225875 tweets
# inserted tweet, now db has 225876 tweets
# inserted tweet, now db has 225877 tweets
# inserted tweet, now db has 225878 tweets
# inserted tweet, now db has 225879 tweets
# inserted tweet, now db has 225880 tweets
# inserted tweet, now db has 225881 tweets
# inserted tweet, now db has 225882 tweets
# inserted tweet, now db has 225883 tweets
# inserted tweet, now db has 225884 tweets
# inserted tweet, now db has 225885 tweets
# inserted tweet, now db has 225886 tweets
# inserted tweet, now db has 225887 tweets
# inserted tweet, now db has 225888 tweets
# inserted tweet, now db has 225889 tweets
# inserted tweet, now db has 225890 tweets
# inserted tweet, now db has 225891 tweets
# inserted tweet, now db has 225892 tweets
# inserted tweet, now db has 225893 tweets
# inserted tweet, now db has 225894 tweets
# inserted tweet, now db has 225895 tweets
# inserted tweet, now db has 225896 tweets
# inserted tweet, now db has 225897 tweets
# inserted tweet, now db has 225898 tweets
# inserted tweet, now db has 225899 tweets
# inserted tweet, now db has 225900 tweets
# inserted tweet, now db has 225901 tweets
# inserted tweet, now db has 225902 tweets
# inserted tweet, now db has 225903 tweets
# inserted tweet, now db has 225904 tweets
# inserted tweet, now db has 225905 tweets
# inserted tweet, now db has 225906 tweets
# inserted tweet, now db has 225907 tweets
# inserted tweet, now db has 225908 tweets
# inserted tweet, now db has 225909 tweets
# inserted tweet, now db has 225910 tweets
# inserted tweet, now db has 225911 tweets
# inserted tweet, now db has 225912 tweets
# inserted tweet, now db has 225913 tweets
# inserted tweet, now db has 225914 tweets
# inserted tweet, now db has 225915 tweets
# inserted tweet, now db has 225916 tweets
# inserted tweet, now db has 225917 tweets
# inserted tweet, now db has 225918 tweets
# inserted tweet, now db has 225919 tweets
# inserted tweet, now db has 225920 tweets
# inserted tweet, now db has 225921 tweets
# inserted tweet, now db has 225922 tweets
# inserted tweet, now db has 225923 tweets
# inserted tweet, now db has 225924 tweets
# inserted tweet, now db has 225925 tweets
# inserted tweet, now db has 225926 tweets
# inserted tweet, now db has 225927 tweets
# inserted tweet, now db has 225928 tweets
# inserted tweet, now db has 225929 tweets
# inserted tweet, now db has 225930 tweets
# inserted tweet, now db has 225931 tweets
# inserted tweet, now db has 225932 tweets
# inserted tweet, now db has 225933 tweets
# inserted tweet, now db has 225934 tweets
# inserted tweet, now db has 225935 tweets
# inserted tweet, now db has 225936 tweets
# inserted tweet, now db has 225937 tweets
# inserted tweet, now db has 225938 tweets
# inserted tweet, now db has 225939 tweets
# inserted tweet, now db has 225940 tweets
# inserted tweet, now db has 225941 tweets
# inserted tweet, now db has 225942 tweets
# inserted tweet, now db has 225943 tweets
# inserted tweet, now db has 225944 tweets
# inserted tweet, now db has 225945 tweets
# inserted tweet, now db has 225946 tweets
# inserted tweet, now db has 225947 tweets
# inserted tweet, now db has 225948 tweets
# inserted tweet, now db has 225949 tweets
# inserted tweet, now db has 225950 tweets
# inserted tweet, now db has 225951 tweets
# inserted tweet, now db has 225952 tweets
# inserted tweet, now db has 225953 tweets
# inserted tweet, now db has 225954 tweets
# inserted tweet, now db has 225955 tweets
# inserted tweet, now db has 225956 tweets
# inserted tweet, now db has 225957 tweets
# inserted tweet, now db has 225958 tweets
# inserted tweet, now db has 225959 tweets
# inserted tweet, now db has 225960 tweets
# inserted tweet, now db has 225961 tweets
# inserted tweet, now db has 225962 tweets
# inserted tweet, now db has 225963 tweets
# inserted tweet, now db has 225964 tweets
# inserted tweet, now db has 225965 tweets
# inserted tweet, now db has 225966 tweets
# inserted tweet, now db has 225967 tweets
# inserted tweet, now db has 225968 tweets
# inserted tweet, now db has 225969 tweets
# inserted tweet, now db has 225970 tweets
# inserted tweet, now db has 225971 tweets
# inserted tweet, now db has 225972 tweets
# inserted tweet, now db has 225973 tweets
# inserted tweet, now db has 225974 tweets
# inserted tweet, now db has 225975 tweets
# inserted tweet, now db has 225976 tweets
# inserted tweet, now db has 225977 tweets
# inserted tweet, now db has 225978 tweets
# inserted tweet, now db has 225979 tweets
# inserted tweet, now db has 225980 tweets
# inserted tweet, now db has 225981 tweets
# inserted tweet, now db has 225982 tweets
# inserted tweet, now db has 225983 tweets
# inserted tweet, now db has 225984 tweets
# inserted tweet, now db has 225985 tweets
# inserted tweet, now db has 225986 tweets
# inserted tweet, now db has 225987 tweets
# inserted tweet, now db has 225988 tweets
# inserted tweet, now db has 225989 tweets
# inserted tweet, now db has 225990 tweets
# inserted tweet, now db has 225991 tweets
# inserted tweet, now db has 225992 tweets
# inserted tweet, now db has 225993 tweets
# inserted tweet, now db has 225994 tweets
# inserted tweet, now db has 225995 tweets
# inserted tweet, now db has 225996 tweets
# inserted tweet, now db has 225997 tweets
# inserted tweet, now db has 225998 tweets
# inserted tweet, now db has 225999 tweets
# inserted tweet, now db has 226000 tweets
# inserted tweet, now db has 226001 tweets
# inserted tweet, now db has 226002 tweets
# inserted tweet, now db has 226003 tweets
# inserted tweet, now db has 226004 tweets
# inserted tweet, now db has 226005 tweets
# inserted tweet, now db has 226006 tweets
# inserted tweet, now db has 226007 tweets
# inserted tweet, now db has 226008 tweets
# inserted tweet, now db has 226009 tweets
# inserted tweet, now db has 226010 tweets
# inserted tweet, now db has 226011 tweets
# inserted tweet, now db has 226012 tweets
# inserted tweet, now db has 226013 tweets
# inserted tweet, now db has 226014 tweets
# inserted tweet, now db has 226015 tweets
# inserted tweet, now db has 226016 tweets
# inserted tweet, now db has 226017 tweets
# inserted tweet, now db has 226018 tweets
# inserted tweet, now db has 226019 tweets
# inserted tweet, now db has 226020 tweets
# inserted tweet, now db has 226021 tweets
# inserted tweet, now db has 226022 tweets
# inserted tweet, now db has 226023 tweets
# inserted tweet, now db has 226024 tweets
# inserted tweet, now db has 226025 tweets
# inserted tweet, now db has 226026 tweets
# inserted tweet, now db has 226027 tweets
# inserted tweet, now db has 226028 tweets
# inserted tweet, now db has 226029 tweets
# inserted tweet, now db has 226030 tweets
# inserted tweet, now db has 226031 tweets
# inserted tweet, now db has 226032 tweets
# inserted tweet, now db has 226033 tweets
# inserted tweet, now db has 226034 tweets
# inserted tweet, now db has 226035 tweets
# inserted tweet, now db has 226036 tweets
# inserted tweet, now db has 226037 tweets
# inserted tweet, now db has 226038 tweets
# inserted tweet, now db has 226039 tweets
# inserted tweet, now db has 226040 tweets
# inserted tweet, now db has 226041 tweets
# inserted tweet, now db has 226042 tweets
# inserted tweet, now db has 226043 tweets
# inserted tweet, now db has 226044 tweets
# inserted tweet, now db has 226045 tweets
# inserted tweet, now db has 226046 tweets
# inserted tweet, now db has 226047 tweets
# inserted tweet, now db has 226048 tweets
# inserted tweet, now db has 226049 tweets
# inserted tweet, now db has 226050 tweets
# inserted tweet, now db has 226051 tweets
# inserted tweet, now db has 226052 tweets
# inserted tweet, now db has 226053 tweets
# inserted tweet, now db has 226054 tweets
# inserted tweet, now db has 226055 tweets
# inserted tweet, now db has 226056 tweets
# inserted tweet, now db has 226057 tweets
# inserted tweet, now db has 226058 tweets
# inserted tweet, now db has 226059 tweets
# inserted tweet, now db has 226060 tweets
# inserted tweet, now db has 226061 tweets
# inserted tweet, now db has 226062 tweets
# inserted tweet, now db has 226063 tweets
# inserted tweet, now db has 226064 tweets
# inserted tweet, now db has 226065 tweets
# inserted tweet, now db has 226066 tweets
# inserted tweet, now db has 226067 tweets
# inserted tweet, now db has 226068 tweets
# inserted tweet, now db has 226069 tweets
# inserted tweet, now db has 226070 tweets
# inserted tweet, now db has 226071 tweets
# inserted tweet, now db has 226072 tweets
# inserted tweet, now db has 226073 tweets
# inserted tweet, now db has 226074 tweets
# inserted tweet, now db has 226075 tweets
# inserted tweet, now db has 226076 tweets
# inserted tweet, now db has 226077 tweets
# inserted tweet, now db has 226078 tweets
# inserted tweet, now db has 226079 tweets
# inserted tweet, now db has 226080 tweets
# inserted tweet, now db has 226081 tweets
# inserted tweet, now db has 226082 tweets
# inserted tweet, now db has 226083 tweets
# inserted tweet, now db has 226084 tweets
# inserted tweet, now db has 226085 tweets
# inserted tweet, now db has 226086 tweets
# inserted tweet, now db has 226087 tweets
# inserted tweet, now db has 226088 tweets
# inserted tweet, now db has 226089 tweets
# inserted tweet, now db has 226090 tweets
# inserted tweet, now db has 226091 tweets
# inserted tweet, now db has 226092 tweets
# inserted tweet, now db has 226093 tweets
# inserted tweet, now db has 226094 tweets
# inserted tweet, now db has 226095 tweets
# inserted tweet, now db has 226096 tweets
# inserted tweet, now db has 226097 tweets
# inserted tweet, now db has 226098 tweets
# inserted tweet, now db has 226099 tweets
# inserted tweet, now db has 226100 tweets
# inserted tweet, now db has 226101 tweets
# inserted tweet, now db has 226102 tweets
# inserted tweet, now db has 226103 tweets
# inserted tweet, now db has 226104 tweets
# inserted tweet, now db has 226105 tweets
# inserted tweet, now db has 226106 tweets
# inserted tweet, now db has 226107 tweets
# inserted tweet, now db has 226108 tweets
# inserted tweet, now db has 226109 tweets
# inserted tweet, now db has 226110 tweets
# inserted tweet, now db has 226111 tweets
# inserted tweet, now db has 226112 tweets
# inserted tweet, now db has 226113 tweets
# inserted tweet, now db has 226114 tweets
# inserted tweet, now db has 226115 tweets
# inserted tweet, now db has 226116 tweets
# inserted tweet, now db has 226117 tweets
# inserted tweet, now db has 226118 tweets
# inserted tweet, now db has 226119 tweets
# inserted tweet, now db has 226120 tweets
# inserted tweet, now db has 226121 tweets
# inserted tweet, now db has 226122 tweets
# inserted tweet, now db has 226123 tweets
# inserted tweet, now db has 226124 tweets
# inserted tweet, now db has 226125 tweets
# inserted tweet, now db has 226126 tweets
# inserted tweet, now db has 226127 tweets
# inserted tweet, now db has 226128 tweets
# inserted tweet, now db has 226129 tweets
# inserted tweet, now db has 226130 tweets
# inserted tweet, now db has 226131 tweets
# inserted tweet, now db has 226132 tweets
# inserted tweet, now db has 226133 tweets
# inserted tweet, now db has 226134 tweets
# inserted tweet, now db has 226135 tweets
# inserted tweet, now db has 226136 tweets
# inserted tweet, now db has 226137 tweets
# inserted tweet, now db has 226138 tweets
# inserted tweet, now db has 226139 tweets
# inserted tweet, now db has 226140 tweets
# inserted tweet, now db has 226141 tweets
# inserted tweet, now db has 226142 tweets
# inserted tweet, now db has 226143 tweets
# inserted tweet, now db has 226144 tweets
# inserted tweet, now db has 226145 tweets
# inserted tweet, now db has 226146 tweets
# inserted tweet, now db has 226147 tweets
# inserted tweet, now db has 226148 tweets
# inserted tweet, now db has 226149 tweets
# inserted tweet, now db has 226150 tweets
# inserted tweet, now db has 226151 tweets
# inserted tweet, now db has 226152 tweets
# inserted tweet, now db has 226153 tweets
# inserted tweet, now db has 226154 tweets
# inserted tweet, now db has 226155 tweets
# inserted tweet, now db has 226156 tweets
# inserted tweet, now db has 226157 tweets
# inserted tweet, now db has 226158 tweets
# inserted tweet, now db has 226159 tweets
# inserted tweet, now db has 226160 tweets
# inserted tweet, now db has 226161 tweets
# inserted tweet, now db has 226162 tweets
# inserted tweet, now db has 226163 tweets
# inserted tweet, now db has 226164 tweets
# inserted tweet, now db has 226165 tweets
# inserted tweet, now db has 226166 tweets
# inserted tweet, now db has 226167 tweets
# inserted tweet, now db has 226168 tweets
# inserted tweet, now db has 226169 tweets
# inserted tweet, now db has 226170 tweets
# inserted tweet, now db has 226171 tweets
# inserted tweet, now db has 226172 tweets
# inserted tweet, now db has 226173 tweets
# inserted tweet, now db has 226174 tweets
# inserted tweet, now db has 226175 tweets
# inserted tweet, now db has 226176 tweets
# inserted tweet, now db has 226177 tweets
# inserted tweet, now db has 226178 tweets
# inserted tweet, now db has 226179 tweets
# inserted tweet, now db has 226180 tweets
# inserted tweet, now db has 226181 tweets
# inserted tweet, now db has 226182 tweets
# inserted tweet, now db has 226183 tweets
# inserted tweet, now db has 226184 tweets
# inserted tweet, now db has 226185 tweets
# inserted tweet, now db has 226186 tweets
# inserted tweet, now db has 226187 tweets
# inserted tweet, now db has 226188 tweets
# inserted tweet, now db has 226189 tweets
# inserted tweet, now db has 226190 tweets
# inserted tweet, now db has 226191 tweets
# inserted tweet, now db has 226192 tweets
# inserted tweet, now db has 226193 tweets
# inserted tweet, now db has 226194 tweets
# inserted tweet, now db has 226195 tweets
# inserted tweet, now db has 226196 tweets
# inserted tweet, now db has 226197 tweets
# inserted tweet, now db has 226198 tweets
# inserted tweet, now db has 226199 tweets
# inserted tweet, now db has 226200 tweets
# inserted tweet, now db has 226201 tweets
# inserted tweet, now db has 226202 tweets
# inserted tweet, now db has 226203 tweets
# inserted tweet, now db has 226204 tweets
# inserted tweet, now db has 226205 tweets
# inserted tweet, now db has 226206 tweets
# inserted tweet, now db has 226207 tweets
# inserted tweet, now db has 226208 tweets
# inserted tweet, now db has 226209 tweets
# inserted tweet, now db has 226210 tweets
# inserted tweet, now db has 226211 tweets
# inserted tweet, now db has 226212 tweets
# inserted tweet, now db has 226213 tweets
# inserted tweet, now db has 226214 tweets
# inserted tweet, now db has 226215 tweets
# inserted tweet, now db has 226216 tweets
# inserted tweet, now db has 226217 tweets
# inserted tweet, now db has 226218 tweets
# inserted tweet, now db has 226219 tweets
# inserted tweet, now db has 226220 tweets
# inserted tweet, now db has 226221 tweets
# inserted tweet, now db has 226222 tweets
# inserted tweet, now db has 226223 tweets
# inserted tweet, now db has 226224 tweets
# inserted tweet, now db has 226225 tweets
# inserted tweet, now db has 226226 tweets
# inserted tweet, now db has 226227 tweets
# inserted tweet, now db has 226228 tweets
# inserted tweet, now db has 226229 tweets
# inserted tweet, now db has 226230 tweets
# inserted tweet, now db has 226231 tweets
# inserted tweet, now db has 226232 tweets
# inserted tweet, now db has 226233 tweets
# inserted tweet, now db has 226234 tweets
# inserted tweet, now db has 226235 tweets
# inserted tweet, now db has 226236 tweets
# inserted tweet, now db has 226237 tweets
# inserted tweet, now db has 226238 tweets
# inserted tweet, now db has 226239 tweets
# inserted tweet, now db has 226240 tweets
# inserted tweet, now db has 226241 tweets
# inserted tweet, now db has 226242 tweets
# inserted tweet, now db has 226243 tweets
# inserted tweet, now db has 226244 tweets
# inserted tweet, now db has 226245 tweets
# inserted tweet, now db has 226246 tweets
# inserted tweet, now db has 226247 tweets
# inserted tweet, now db has 226248 tweets
# inserted tweet, now db has 226249 tweets
# inserted tweet, now db has 226250 tweets
# inserted tweet, now db has 226251 tweets
# inserted tweet, now db has 226252 tweets
# inserted tweet, now db has 226253 tweets
# inserted tweet, now db has 226254 tweets
# inserted tweet, now db has 226255 tweets
# inserted tweet, now db has 226256 tweets
# inserted tweet, now db has 226257 tweets
# inserted tweet, now db has 226258 tweets
# inserted tweet, now db has 226259 tweets
# inserted tweet, now db has 226260 tweets
# inserted tweet, now db has 226261 tweets
# inserted tweet, now db has 226262 tweets
# inserted tweet, now db has 226263 tweets
# inserted tweet, now db has 226264 tweets
# inserted tweet, now db has 226265 tweets
# inserted tweet, now db has 226266 tweets
# ...
# inserted tweet, now db has 231322 tweets
# inserted tweet, now db has 231323 tweets
# inserted tweet, now db has 231324 tweets
# inserted tweet, now db has 231325 tweets
# inserted tweet, now db has 231326 tweets
# inserted tweet, now db has 231327 tweets
# inserted tweet, now db has 231328 tweets
# inserted tweet, now db has 231329 tweets
# inserted tweet, now db has 231330 tweets
# inserted tweet, now db has 231331 tweets
# inserted tweet, now db has 231332 tweets
# inserted tweet, now db has 231333 tweets
# inserted tweet, now db has 231334 tweets
# inserted tweet, now db has 231335 tweets
# inserted tweet, now db has 231336 tweets
# inserted tweet, now db has 231337 tweets
# inserted tweet, now db has 231338 tweets
# inserted tweet, now db has 231339 tweets
# inserted tweet, now db has 231340 tweets
# inserted tweet, now db has 231341 tweets
# inserted tweet, now db has 231342 tweets
# inserted tweet, now db has 231343 tweets
# inserted tweet, now db has 231344 tweets
# inserted tweet, now db has 231345 tweets
# inserted tweet, now db has 231346 tweets
# inserted tweet, now db has 231347 tweets
# inserted tweet, now db has 231348 tweets
# inserted tweet, now db has 231349 tweets
# inserted tweet, now db has 231350 tweets
# inserted tweet, now db has 231351 tweets
# inserted tweet, now db has 231352 tweets
# inserted tweet, now db has 231353 tweets
# inserted tweet, now db has 231354 tweets
# inserted tweet, now db has 231355 tweets
# inserted tweet, now db has 231356 tweets
# inserted tweet, now db has 231357 tweets
# inserted tweet, now db has 231358 tweets
# inserted tweet, now db has 231359 tweets
# inserted tweet, now db has 231360 tweets
# inserted tweet, now db has 231361 tweets
# inserted tweet, now db has 231362 tweets
# inserted tweet, now db has 231363 tweets
# inserted tweet, now db has 231364 tweets
# inserted tweet, now db has 231365 tweets
# inserted tweet, now db has 231366 tweets
# inserted tweet, now db has 231367 tweets
# inserted tweet, now db has 231368 tweets
# inserted tweet, now db has 231369 tweets
# inserted tweet, now db has 231370 tweets
# inserted tweet, now db has 231371 tweets
# inserted tweet, now db has 231372 tweets
# inserted tweet, now db has 231373 tweets
# inserted tweet, now db has 231374 tweets
# inserted tweet, now db has 231375 tweets
# inserted tweet, now db has 231376 tweets
# inserted tweet, now db has 231377 tweets
# inserted tweet, now db has 231378 tweets
# inserted tweet, now db has 231379 tweets
# inserted tweet, now db has 231380 tweets
# inserted tweet, now db has 231381 tweets
# inserted tweet, now db has 231382 tweets
# inserted tweet, now db has 231383 tweets
# inserted tweet, now db has 231384 tweets
# inserted tweet, now db has 231385 tweets
# inserted tweet, now db has 231386 tweets
# inserted tweet, now db has 231387 tweets
# inserted tweet, now db has 231388 tweets
# inserted tweet, now db has 231389 tweets
# inserted tweet, now db has 231390 tweets
# inserted tweet, now db has 231391 tweets
# inserted tweet, now db has 231392 tweets
# inserted tweet, now db has 231393 tweets
# inserted tweet, now db has 231394 tweets
# inserted tweet, now db has 231395 tweets
# inserted tweet, now db has 231396 tweets
# inserted tweet, now db has 231397 tweets
# inserted tweet, now db has 231398 tweets
# inserted tweet, now db has 231399 tweets
# inserted tweet, now db has 231400 tweets
# inserted tweet, now db has 231401 tweets
# inserted tweet, now db has 231402 tweets
# inserted tweet, now db has 231403 tweets
# inserted tweet, now db has 231404 tweets
# inserted tweet, now db has 231405 tweets
# inserted tweet, now db has 231406 tweets
# inserted tweet, now db has 231407 tweets
# inserted tweet, now db has 231408 tweets
# inserted tweet, now db has 231409 tweets
# inserted tweet, now db has 231410 tweets
# inserted tweet, now db has 231411 tweets
# inserted tweet, now db has 231412 tweets
# inserted tweet, now db has 231413 tweets
# inserted tweet, now db has 231414 tweets
# inserted tweet, now db has 231415 tweets
# inserted tweet, now db has 231416 tweets
# inserted tweet, now db has 231417 tweets
# inserted tweet, now db has 231418 tweets
# inserted tweet, now db has 231419 tweets
# inserted tweet, now db has 231420 tweets
# inserted tweet, now db has 231421 tweets
# inserted tweet, now db has 231422 tweets
# inserted tweet, now db has 231423 tweets
# inserted tweet, now db has 231424 tweets
# inserted tweet, now db has 231425 tweets
# inserted tweet, now db has 231426 tweets
# inserted tweet, now db has 231427 tweets
# inserted tweet, now db has 231428 tweets
# inserted tweet, now db has 231429 tweets
# inserted tweet, now db has 231430 tweets
# inserted tweet, now db has 231431 tweets
# inserted tweet, now db has 231432 tweets
# inserted tweet, now db has 231433 tweets
# inserted tweet, now db has 231434 tweets
# inserted tweet, now db has 231435 tweets
# inserted tweet, now db has 231436 tweets
# inserted tweet, now db has 231437 tweets
# inserted tweet, now db has 231438 tweets
# inserted tweet, now db has 231439 tweets
# inserted tweet, now db has 231440 tweets
# inserted tweet, now db has 231441 tweets
# inserted tweet, now db has 231442 tweets
# inserted tweet, now db has 231443 tweets
# inserted tweet, now db has 231444 tweets
# inserted tweet, now db has 231445 tweets
# inserted tweet, now db has 231446 tweets
# inserted tweet, now db has 231447 tweets
# inserted tweet, now db has 231448 tweets
# inserted tweet, now db has 231449 tweets
# inserted tweet, now db has 231450 tweets
# inserted tweet, now db has 231451 tweets
# inserted tweet, now db has 231452 tweets
# inserted tweet, now db has 231453 tweets
# inserted tweet, now db has 231454 tweets
# inserted tweet, now db has 231455 tweets
# inserted tweet, now db has 231456 tweets
# inserted tweet, now db has 231457 tweets
# inserted tweet, now db has 231458 tweets
# inserted tweet, now db has 231459 tweets
# inserted tweet, now db has 231460 tweets
# inserted tweet, now db has 231461 tweets
# inserted tweet, now db has 231462 tweets
# inserted tweet, now db has 231463 tweets
# inserted tweet, now db has 231464 tweets
# inserted tweet, now db has 231465 tweets
# inserted tweet, now db has 231466 tweets
# inserted tweet, now db has 231467 tweets
# inserted tweet, now db has 231468 tweets
# inserted tweet, now db has 231469 tweets
# inserted tweet, now db has 231470 tweets
# inserted tweet, now db has 231471 tweets
# inserted tweet, now db has 231472 tweets
# inserted tweet, now db has 231473 tweets
# inserted tweet, now db has 231474 tweets
# inserted tweet, now db has 231475 tweets
# inserted tweet, now db has 231476 tweets
# inserted tweet, now db has 231477 tweets
# inserted tweet, now db has 231478 tweets
# inserted tweet, now db has 231479 tweets
# inserted tweet, now db has 231480 tweets
# inserted tweet, now db has 231481 tweets
# inserted tweet, now db has 231482 tweets
# inserted tweet, now db has 231483 tweets
# inserted tweet, now db has 231484 tweets
# inserted tweet, now db has 231485 tweets
# inserted tweet, now db has 231486 tweets
# inserted tweet, now db has 231487 tweets
# inserted tweet, now db has 231488 tweets
# inserted tweet, now db has 231489 tweets
# inserted tweet, now db has 231490 tweets
# inserted tweet, now db has 231491 tweets
# inserted tweet, now db has 231492 tweets
# inserted tweet, now db has 231493 tweets
# inserted tweet, now db has 231494 tweets
# inserted tweet, now db has 231495 tweets
# inserted tweet, now db has 231496 tweets
# inserted tweet, now db has 231497 tweets
# inserted tweet, now db has 231498 tweets
# inserted tweet, now db has 231499 tweets
# inserted tweet, now db has 231500 tweets
# inserted tweet, now db has 231501 tweets
# inserted tweet, now db has 231502 tweets
# inserted tweet, now db has 231503 tweets
# inserted tweet, now db has 231504 tweets
# inserted tweet, now db has 231505 tweets
# inserted tweet, now db has 231506 tweets
# inserted tweet, now db has 231507 tweets
# inserted tweet, now db has 231508 tweets
# inserted tweet, now db has 231509 tweets
# inserted tweet, now db has 231510 tweets
# inserted tweet, now db has 231511 tweets
# inserted tweet, now db has 231512 tweets
# inserted tweet, now db has 231513 tweets
# inserted tweet, now db has 231514 tweets
# inserted tweet, now db has 231515 tweets
# inserted tweet, now db has 231516 tweets
# inserted tweet, now db has 231517 tweets
# inserted tweet, now db has 231518 tweets
# inserted tweet, now db has 231519 tweets
# inserted tweet, now db has 231520 tweets
# inserted tweet, now db has 231521 tweets
# inserted tweet, now db has 231522 tweets
# inserted tweet, now db has 231523 tweets
# inserted tweet, now db has 231524 tweets
# inserted tweet, now db has 231525 tweets
# inserted tweet, now db has 231526 tweets
# inserted tweet, now db has 231527 tweets
# inserted tweet, now db has 231528 tweets
# inserted tweet, now db has 231529 tweets
# inserted tweet, now db has 231530 tweets
# inserted tweet, now db has 231531 tweets
# inserted tweet, now db has 231532 tweets
# inserted tweet, now db has 231533 tweets
# inserted tweet, now db has 231534 tweets
# inserted tweet, now db has 231535 tweets
# inserted tweet, now db has 231536 tweets
# inserted tweet, now db has 231537 tweets
# inserted tweet, now db has 231538 tweets
# inserted tweet, now db has 231539 tweets
# inserted tweet, now db has 231540 tweets
# inserted tweet, now db has 231541 tweets
# inserted tweet, now db has 231542 tweets
# ---------------------------------------------------------------------------
# SysCallError                              Traceback (most recent call last)
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1638                     if errno != 0:
# -> 1639                         raise SysCallError(errno, errorcode.get(errno))
#    1640                 raise SysCallError(-1, "Unexpected EOF")
#
# SysCallError: (54, 'ECONNRESET')
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/response.py in _error_catcher(self)
#     359             try:
# --> 360                 yield
#     361
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     441                 cache_content = False
# --> 442                 data = self._fp.read(amt)
#     443                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/http/client.py in read(self, amt)
#     458             b = bytearray(amt)
# --> 459             n = self.readinto(b)
#     460             return memoryview(b)[:n].tobytes()
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/http/client.py in readinto(self, b)
#     492         if self.chunked:
# --> 493             return self._readinto_chunked(b)
#     494
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/http/client.py in _readinto_chunked(self, b)
#     592                 if len(mvb) <= chunk_left:
# --> 593                     n = self._safe_readinto(mvb)
#     594                     self.chunk_left = chunk_left - n
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/http/client.py in _safe_readinto(self, b)
#     637             else:
# --> 638                 n = self.fp.readinto(mvb)
#     639             if not n:
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/socket.py in readinto(self, b)
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     301             else:
# --> 302                 raise SocketError(str(e))
#     303         except OpenSSL.SSL.ZeroReturnError as e:
#
# OSError: (54, 'ECONNRESET')
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# <ipython-input-44-b9f6a2ca1710> in <module>
#       1 # Filter
# ----> 2 myStream.filter(track=['covid', '#covid', 'shelter', 'COVID', '#COVID', 'pandemic'])
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/tweepy/streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/tweepy/streaming.py in _run(self)
#     318             # call a handler first so that the exception can be logged.
#     319             self.listener.on_exception(exc_info[1])
# --> 320             six.reraise(*exc_info)
#     321
#     322     def _data(self, data):
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/six.py in reraise(tp, value, tb)
#     691             if value.__traceback__ is not tb:
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#     695             value = None
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/tweepy/streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/tweepy/streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     457                         # raised during streaming, so all calls with incorrect
#     458                         # Content-Length are caught.
# --> 459                         raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#     460
#     461         if data:
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/contextlib.py in __exit__(self, type, value, traceback)
#      97                 value = type()
#      98             try:
# ---> 99                 self.gen.throw(type, value, traceback)
#     100             except StopIteration as exc:
#     101                 # Suppress StopIteration *unless* it's the same exception that
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/urllib3/response.py in _error_catcher(self)
#     376             except (HTTPException, SocketError) as e:
#     377                 # This includes IncompleteRead.
# --> 378                 raise ProtocolError('Connection broken: %r' % e, e)
#     379
#     380             # If no exception is thrown, we should avoid cleaning up
#
# ProtocolError: ('Connection broken: OSError("(54, \'ECONNRESET\')",)', OSError("(54, 'ECONNRESET')",))

# %%
# List the number of tweets
covid_tweets.count_documents(filter={})
# Out:
# 231542

# %% [markdown]
# # View tweet properties

# %%
# Let's view a tweet - caution language is not mine
one = covid_tweets.find_one()

# %% [markdown]
# ## Load the tweets into a dataframe

# %%
# Load tweets into a list tweet items
document_list = list(covid_tweets.find(filter={}))

# %%
# Convert list to dataframe and show all columns
df = pd.DataFrame(document_list) 
pd.set_option('display.max_columns', None)
df.head()
# Out:
#                         _id                      created_at  \
# 0  5ea86e63f62c72daf5bbcc93  Tue Apr 28 17:56:45 +0000 2020
# 1  5ea86e9af62c72daf5bbcc94  Tue Apr 28 17:57:41 +0000 2020
# 2  5ea86ed5f62c72daf5bbcc95  Tue Apr 28 17:58:40 +0000 2020
# 3  5ea86ed5f62c72daf5bbcc96  Tue Apr 28 17:58:40 +0000 2020
# 4  5ea86ed5f62c72daf5bbcc97  Tue Apr 28 17:58:40 +0000 2020
#
#                     id               id_str  \
# 0  1255194256937046018  1255194256937046018
# 1  1255194489511202816  1255194489511202816
# 2  1255194736991797250  1255194736991797250
# 3  1255194737604268034  1255194737604268034
# 4  1255194737578872832  1255194737578872832
#
#                                                 text  \
# 0  RT @threadreaderapp: @TimeMayHeal Bonjour, the...
# 1  RT @mitchellvii: I don't care if COVID-19 had ...
# 2  Act now and call on the President to take back...
# 3                                            A dream
# 4                 pelo amor de deus eu vo passar mal
#
#                                               source  truncated  \
# 0  <a href="http://twitter.com/download/android" ...      False
# 1  <a href="http://twitter.com/download/iphone" r...      False
# 2  <a href="http://phone2action.com" rel="nofollo...       True
# 3  <a href="http://twitter.com/download/iphone" r...      False
# 4  <a href="http://twitter.com/download/iphone" r...      False
#
#    in_reply_to_status_id in_reply_to_status_id_str  in_reply_to_user_id  \
# 0                    NaN                      None                  NaN
# 1                    NaN                      None                  NaN
# 2                    NaN                      None                  NaN
# 3                    NaN                      None                  NaN
# 4                    NaN                      None                  NaN
#
#   in_reply_to_user_id_str in_reply_to_screen_name  \
# 0                    None                    None
# 1                    None                    None
# 2                    None                    None
# 3                    None                    None
# 4                    None                    None
#
#                                                 user   geo coordinates place  \
# 0  {'id': 22647819, 'id_str': '22647819', 'name':...  None        None  None
# 1  {'id': 1050871427979730944, 'id_str': '1050871...  None        None  None
# 2  {'id': 930743156, 'id_str': '930743156', 'name...  None        None  None
# 3  {'id': 34645167, 'id_str': '34645167', 'name':...  None        None  None
# 4  {'id': 883122567262896128, 'id_str': '88312256...  None        None  None
#
#   contributors                                   retweeted_status  \
# 0         None  {'created_at': 'Tue Apr 28 17:36:46 +0000 2020...
# 1         None  {'created_at': 'Tue Apr 28 16:49:28 +0000 2020...
# 2         None                                                NaN
# 3         None                                                NaN
# 4         None                                                NaN
#
#    is_quote_status  quote_count  reply_count  retweet_count  favorite_count  \
# 0            False            0            0              0               0
# 1            False            0            0              0               0
# 2            False            0            0              0               0
# 3             True            0            0              0               0
# 4             True            0            0              0               0
#
#                                             entities  favorited  retweeted  \
# 0  {'hashtags': [], 'urls': [], 'user_mentions': ...      False      False
# 1  {'hashtags': [], 'urls': [], 'user_mentions': ...      False      False
# 2  {'hashtags': [], 'urls': [{'url': 'https://t.c...      False      False
# 3  {'hashtags': [], 'urls': [], 'user_mentions': ...      False      False
# 4  {'hashtags': [], 'urls': [], 'user_mentions': ...      False      False
#
#   filter_level lang   timestamp_ms display_text_range  \
# 0          low   en  1588096605892                NaN
# 1          low   en  1588096661342                NaN
# 2          low   en  1588096720346           [0, 140]
# 3          low   en  1588096720492                NaN
# 4          low   pt  1588096720486                NaN
#
#                                       extended_tweet possibly_sensitive  \
# 0                                                NaN                NaN
# 1                                                NaN                NaN
# 2  {'full_text': 'Act now and call on the Preside...               True
# 3                                                NaN                NaN
# 4                                                NaN                NaN
#
#    quoted_status_id quoted_status_id_str  \
# 0               NaN                  NaN
# 1               NaN                  NaN
# 2               NaN                  NaN
# 3      1.255107e+18  1255106762736271363
# 4      1.255182e+18  1255182474231103490
#
#                                        quoted_status  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  {'created_at': 'Tue Apr 28 12:09:05 +0000 2020...
# 4  {'created_at': 'Tue Apr 28 17:09:56 +0000 2020...
#
#                              quoted_status_permalink extended_entities  \
# 0                                                NaN               NaN
# 1                                                NaN               NaN
# 2                                                NaN               NaN
# 3  {'url': 'https://t.co/yHhlc5ii47', 'expanded':...               NaN
# 4  {'url': 'https://t.co/LJAu0IA4MB', 'expanded':...               NaN
#
#   withheld_in_countries
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
# Information about the tweet data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231542 entries, 0 to 231541
# Data columns (total 38 columns):
# _id                          231542 non-null object
# created_at                   231542 non-null object
# id                           231542 non-null int64
# id_str                       231542 non-null object
# text                         231542 non-null object
# source                       231542 non-null object
# truncated                    231542 non-null bool
# in_reply_to_status_id        15812 non-null float64
# in_reply_to_status_id_str    15812 non-null object
# in_reply_to_user_id          17907 non-null float64
# in_reply_to_user_id_str      17907 non-null object
# in_reply_to_screen_name      17907 non-null object
# user                         231542 non-null object
# geo                          110 non-null object
# coordinates                  110 non-null object
# place                        2040 non-null object
# contributors                 0 non-null object
# retweeted_status             164467 non-null object
# is_quote_status              231542 non-null bool
# quote_count                  231542 non-null int64
# reply_count                  231542 non-null int64
# retweet_count                231542 non-null int64
# favorite_count               231542 non-null int64
# entities                     231542 non-null object
# favorited                    231542 non-null bool
# retweeted                    231542 non-null bool
# filter_level                 231542 non-null object
# lang                         231542 non-null object
# timestamp_ms                 231542 non-null object
# display_text_range           23612 non-null object
# extended_tweet               33699 non-null object
# possibly_sensitive           55483 non-null object
# quoted_status_id             55401 non-null float64
# quoted_status_id_str         55401 non-null object
# quoted_status                55391 non-null object
# quoted_status_permalink      55391 non-null object
# extended_entities            13003 non-null object
# withheld_in_countries        69 non-null object
# dtypes: bool(4), float64(3), int64(5), object(26)
# memory usage: 60.9+ MB

# %%
# Describe tweets
df.describe()
# Out:
#                  id  in_reply_to_status_id  in_reply_to_user_id  quote_count  \
# count  2.315420e+05           1.581200e+04         1.790700e+04     231542.0
# mean   1.255398e+18           1.254648e+18         2.766132e+17          0.0
# std    1.945928e+14           1.911271e+16         4.627274e+17          0.0
# min    1.255194e+18           1.538469e+10         8.880000e+02          0.0
# 25%    1.255200e+18           1.255188e+18         5.812246e+07          0.0
# 50%    1.255246e+18           1.255234e+18         4.315477e+08          0.0
# 75%    1.255593e+18           1.255574e+18         7.576525e+17          0.0
# max    1.255618e+18           1.255618e+18         1.255603e+18          0.0
#
#        reply_count  retweet_count  favorite_count  quoted_status_id
# count     231542.0       231542.0        231542.0      5.540100e+04
# mean           0.0            0.0             0.0      1.254095e+18
# std            0.0            0.0             0.0      2.271662e+16
# min            0.0            0.0             0.0      2.420939e+09
# 25%            0.0            0.0             0.0      1.255059e+18
# 50%            0.0            0.0             0.0      1.255191e+18
# 75%            0.0            0.0             0.0      1.255523e+18
# max            0.0            0.0             0.0      1.255618e+18

# %% [markdown]
# ## Save df with Pickle

# %%
df.to_pickle("data/dummy.pkl")

# %% [markdown]
# ## Countries who withheld tweets

# %%
# Look at tweets withheld in countries
withheld_countries_list = np.array(df.withheld_in_countries)

# intilize a null list 
unique_list = [] 
  
# traverse for all elements 
for x in withheld_countries_list: 
    # check if exists in unique_list or not 
    if x not in unique_list: 
        unique_list.append(x) 
# print list 
unique_list
# Out:
# [nan, ['TR'], ['DE'], ['IN'], ['DE', 'FR'], ['DE', 'RU'], ['RU']]

# %% [markdown]
# The countries who withheld tweets are Turkey, Germany (DE), Indonesia, France, Russian Federation

# %% [markdown]
# ## Other tweet properties

# %%
# Tweets retreated - these tweets are new and haven't had a chance to be retweeted 
# Although there are tweets that are retweets of other tweets
df['retweeted'].value_counts()
# Out:
# False    231542
# Name: retweeted, dtype: int64

# %% [markdown]
# # Merged tweets
# Obtained tweets in other streamer - merging the two

# %%
# Load tweet from other streamer
df2 = pickle.load( open( "save.p", "rb" ) )

# %%
df2.head()
# Out:
#                         _id                      created_at  \
# 0  5eac83c3cc0f4e6d62883bff  Fri May 01 20:17:02 +0000 2020
# 1  5eac844ecc0f4e6d62883c00  Fri May 01 20:19:21 +0000 2020
# 2  5eac84b2cc0f4e6d62883c01  Fri May 01 20:21:01 +0000 2020
# 3  5eac8518cc0f4e6d62883c02  Fri May 01 20:22:43 +0000 2020
# 4  5eac8518cc0f4e6d62883c03  Fri May 01 20:22:43 +0000 2020
#
#                     id               id_str  \
# 0  1256316721855512576  1256316721855512576
# 1  1256317305249652736  1256317305249652736
# 2  1256317723451113472  1256317723451113472
# 3  1256318153929310209  1256318153929310209
# 4  1256318154097037313  1256318154097037313
#
#                                                 text  \
# 0  RT @mmcvenaragua: Es necesario el esfuerzo de ...
# 1  RT @GautengProvince: #COVID19 | GAUTENG COVID-...
# 2  COVID-19 coverage is in the news 24-7.   Local...
# 3  @Dewayangitu Sy sbg warga Jatim jg ngga sepaka...
# 4  RT @BillGates: There are over 100 different co...
#
#                                               source  truncated  \
# 0  <a href="http://twitter.com/download/android" ...      False
# 1  <a href="http://twitter.com/download/android" ...      False
# 2  <a href="https://mobile.twitter.com" rel="nofo...       True
# 3  <a href="http://twitter.com/download/android" ...       True
# 4  <a href="http://twitter.com/download/android" ...      False
#
#    in_reply_to_status_id in_reply_to_status_id_str  in_reply_to_user_id  \
# 0                    NaN                      None                  NaN
# 1                    NaN                      None                  NaN
# 2                    NaN                      None                  NaN
# 3           1.256284e+18       1256284399827468288          101415677.0
# 4                    NaN                      None                  NaN
#
#   in_reply_to_user_id_str in_reply_to_screen_name  \
# 0                    None                    None
# 1                    None                    None
# 2                    None                    None
# 3               101415677             Dewayangitu
# 4                    None                    None
#
#                                                 user   geo coordinates place  \
# 0  {'id': 1242896396954546182, 'id_str': '1242896...  None        None  None
# 1  {'id': 163899426, 'id_str': '163899426', 'name...  None        None  None
# 2  {'id': 18147841, 'id_str': '18147841', 'name':...  None        None  None
# 3  {'id': 312014527, 'id_str': '312014527', 'name...  None        None  None
# 4  {'id': 133974399, 'id_str': '133974399', 'name...  None        None  None
#
#   contributors                                   retweeted_status  \
# 0         None  {'created_at': 'Thu Apr 30 18:17:25 +0000 2020...
# 1         None  {'created_at': 'Fri May 01 14:35:34 +0000 2020...
# 2         None                                                NaN
# 3         None                                                NaN
# 4         None  {'created_at': 'Fri May 01 18:39:08 +0000 2020...
#
#    is_quote_status  quote_count  reply_count  retweet_count  favorite_count  \
# 0            False            0            0              0               0
# 1            False            0            0              0               0
# 2            False            0            0              0               0
# 3            False            0            0              0               0
# 4            False            0            0              0               0
#
#                                             entities  favorited  retweeted  \
# 0  {'hashtags': [], 'urls': [], 'user_mentions': ...      False      False
# 1  {'hashtags': [{'text': 'COVID19', 'indices': [...      False      False
# 2  {'hashtags': [], 'urls': [{'url': 'https://t.c...      False      False
# 3  {'hashtags': [], 'urls': [{'url': 'https://t.c...      False      False
# 4  {'hashtags': [], 'urls': [], 'user_mentions': ...      False      False
#
#   filter_level lang   timestamp_ms  \
# 0          low   es  1588364222383
# 1          low   en  1588364361475
# 2          low   en  1588364461182
# 3          low   in  1588364563816
# 4          low   en  1588364563856
#
#                                       extended_tweet display_text_range  \
# 0                                                NaN                NaN
# 1                                                NaN                NaN
# 2  {'full_text': 'COVID-19 coverage is in the new...                NaN
# 3  {'full_text': '@Dewayangitu Sy sbg warga Jatim...          [13, 140]
# 4                                                NaN                NaN
#
#   possibly_sensitive  quoted_status_id quoted_status_id_str quoted_status  \
# 0                NaN               NaN                  NaN           NaN
# 1                NaN               NaN                  NaN           NaN
# 2                NaN               NaN                  NaN           NaN
# 3                NaN               NaN                  NaN           NaN
# 4                NaN               NaN                  NaN           NaN
#
#   quoted_status_permalink extended_entities withheld_in_countries
# 0                     NaN               NaN                   NaN
# 1                     NaN               NaN                   NaN
# 2                     NaN               NaN                   NaN
# 3                     NaN               NaN                   NaN
# 4                     NaN               NaN                   NaN

# %%
# Append the two into one dataframe
twitter_df = df.append(df2)
print(len(twitter_df))
twitter_df.head()
# Out:
# /Users/shirlwilliams/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
# 339187
#                         _id contributors coordinates  \
# 0  5ea86e63f62c72daf5bbcc93         None        None
# 1  5ea86e9af62c72daf5bbcc94         None        None
# 2  5ea86ed5f62c72daf5bbcc95         None        None
# 3  5ea86ed5f62c72daf5bbcc96         None        None
# 4  5ea86ed5f62c72daf5bbcc97         None        None
#
#                        created_at display_text_range  \
# 0  Tue Apr 28 17:56:45 +0000 2020                NaN
# 1  Tue Apr 28 17:57:41 +0000 2020                NaN
# 2  Tue Apr 28 17:58:40 +0000 2020           [0, 140]
# 3  Tue Apr 28 17:58:40 +0000 2020                NaN
# 4  Tue Apr 28 17:58:40 +0000 2020                NaN
#
#                                             entities extended_entities  \
# 0  {'hashtags': [], 'urls': [], 'user_mentions': ...               NaN
# 1  {'hashtags': [], 'urls': [], 'user_mentions': ...               NaN
# 2  {'hashtags': [], 'urls': [{'url': 'https://t.c...               NaN
# 3  {'hashtags': [], 'urls': [], 'user_mentions': ...               NaN
# 4  {'hashtags': [], 'urls': [], 'user_mentions': ...               NaN
#
#                                       extended_tweet  favorite_count  \
# 0                                                NaN               0
# 1                                                NaN               0
# 2  {'full_text': 'Act now and call on the Preside...               0
# 3                                                NaN               0
# 4                                                NaN               0
#
#    favorited filter_level   geo                   id               id_str  \
# 0      False          low  None  1255194256937046018  1255194256937046018
# 1      False          low  None  1255194489511202816  1255194489511202816
# 2      False          low  None  1255194736991797250  1255194736991797250
# 3      False          low  None  1255194737604268034  1255194737604268034
# 4      False          low  None  1255194737578872832  1255194737578872832
#
#   in_reply_to_screen_name  in_reply_to_status_id in_reply_to_status_id_str  \
# 0                    None                    NaN                      None
# 1                    None                    NaN                      None
# 2                    None                    NaN                      None
# 3                    None                    NaN                      None
# 4                    None                    NaN                      None
#
#    in_reply_to_user_id in_reply_to_user_id_str  is_quote_status lang place  \
# 0                  NaN                    None            False   en  None
# 1                  NaN                    None            False   en  None
# 2                  NaN                    None            False   en  None
# 3                  NaN                    None             True   en  None
# 4                  NaN                    None             True   pt  None
#
#   possibly_sensitive  quote_count  \
# 0                NaN            0
# 1                NaN            0
# 2               True            0
# 3                NaN            0
# 4                NaN            0
#
#                                        quoted_status  quoted_status_id  \
# 0                                                NaN               NaN
# 1                                                NaN               NaN
# 2                                                NaN               NaN
# 3  {'created_at': 'Tue Apr 28 12:09:05 +0000 2020...      1.255107e+18
# 4  {'created_at': 'Tue Apr 28 17:09:56 +0000 2020...      1.255182e+18
#
#   quoted_status_id_str                            quoted_status_permalink  \
# 0                  NaN                                                NaN
# 1                  NaN                                                NaN
# 2                  NaN                                                NaN
# 3  1255106762736271363  {'url': 'https://t.co/yHhlc5ii47', 'expanded':...
# 4  1255182474231103490  {'url': 'https://t.co/LJAu0IA4MB', 'expanded':...
#
#    reply_count  retweet_count  retweeted  \
# 0            0              0      False
# 1            0              0      False
# 2            0              0      False
# 3            0              0      False
# 4            0              0      False
#
#                                     retweeted_status  \
# 0  {'created_at': 'Tue Apr 28 17:36:46 +0000 2020...
# 1  {'created_at': 'Tue Apr 28 16:49:28 +0000 2020...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://phone2action.com" rel="nofollo...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text   timestamp_ms  \
# 0  RT @threadreaderapp: @TimeMayHeal Bonjour, the...  1588096605892
# 1  RT @mitchellvii: I don't care if COVID-19 had ...  1588096661342
# 2  Act now and call on the President to take back...  1588096720346
# 3                                            A dream  1588096720492
# 4                 pelo amor de deus eu vo passar mal  1588096720486
#
#    truncated                                               user  \
# 0      False  {'id': 22647819, 'id_str': '22647819', 'name':...
# 1      False  {'id': 1050871427979730944, 'id_str': '1050871...
# 2       True  {'id': 930743156, 'id_str': '930743156', 'name...
# 3      False  {'id': 34645167, 'id_str': '34645167', 'name':...
# 4      False  {'id': 883122567262896128, 'id_str': '88312256...
#
#   withheld_in_countries
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %% [markdown]
#  # Save twitter_df for other files
#  Use Pickle to save file as twitter_df

# %%
 pickle.dump( df, open( "twitter_df.p", "wb" ) )
